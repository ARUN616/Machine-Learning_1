# %%
import pandas as pd

# %%
data=pd.read_csv('insurance_pre.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=data[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=data[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
           'splitter':['best', 'random'],
           'max_features':[ 'sqrt', 'log2']}

grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
re
# Out:
# {'mean_fit_time': array([0.01308775, 0.01143622, 0.00985684, 0.00476017, 0.01562691,
#         0.01250014, 0.01562085, 0.00878582, 0.03611689, 0.0294034 ,
#         0.0292367 , 0.02169485, 0.0133924 , 0.00940022, 0.01430922,
#         0.01062846]),
#  'std_fit_time': array([1.91057277e-03, 3.17340586e-03, 2.32298374e-03, 6.28864455e-03,
#         1.46195504e-06, 6.25007153e-03, 5.17889938e-06, 7.38355113e-03,
#         1.08641020e-02, 1.08275965e-02, 2.82301783e-03, 7.26893686e-03,
#         3.70357298e-03, 5.12858643e-03, 6.90742822e-03, 6.53721052e-03]),
#  'mean_score_time': array([0.00668325, 0.00577002, 0.00476184, 0.01250749, 0.00625   ,
#         0.0062479 , 0.00855494, 0.00994005, 0.00080066, 0.00439725,
#         0.01006551, 0.00730333, 0.0087574 , 0.00743384, 0.00482183,
#         0.00453568]),
#  'std_score_time': array([0.00209708, 0.00169979, 0.00629153, 0.00625374, 0.00765466,
#         0.00765209, 0.00714379, 0.00354699, 0.00160131, 0.00368927,
#         0.00594276, 0.00662168, 0.00803112, 0.00493499, 0.0073889 ,
#         0.00618977]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_features': 'sqrt',
#    'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'sqrt',
#    'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'log2',
#    'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}],
#  'split0_test_score': array([0.61899513, 0.65711837, 0.60047472, 0.66912354, 0.52561956,
#         0.58849379, 0.62271739, 0.59505486, 0.70018913, 0.54491273,
#         0.559575  , 0.54025005, 0.63730936, 0.50155602, 0.69370441,
#         0.60904563]),
#  'split1_test_score': array([0.59977861, 0.51687023, 0.63508873, 0.54327992, 0.33956595,
#         0.64825566, 0.60662025, 0.54469826, 0.5554855 , 0.4750619 ,
#         0.60085834, 0.62405811, 0.52578449, 0.65191063, 0.64735984,
#         0.61812852]),
#  'split2_test_score': array([0.71053925, 0.34601787, 0.29806043, 0.75334082, 0.61252981,
#         0.58425111, 0.63971   , 0.73751351, 0.68883947, 0.45952025,
#         0.61555484, 0.67716904, 0.69102279, 0.55283135, 0.6062567 ,
#         0.67582899]),
#  'split3_test_score': array([0.70050351, 0.22213671, 0.6355435 , 0.61938227, 0.47524127,
#         0.5742221 , 0.55386827, 0.67346957, 0.50931777, 0.50801391,
#         0.6184487 , 0.64807207, 0.56336884, 0.4823618 , 0.57434087,
#         0.57262426]),
#  'split4_test_score': array([0.66248985, 0.53044203, 0.69532364, 0.63135719, 0.5925316 ,
#         0.65737052, 0.67881675, 0.58663465, 0.60652205, 0.66428597,
#         0.61339211, 0.56843473, 0.66756832, 0.56357752, 0.60972527,
#         0.53469628]),
#  'mean_test_score': array([0.65846127, 0.45451704, 0.57289821, 0.64329675, 0.50909764,
#         0.61051864, 0.62034653, 0.62747417, 0.61207078, 0.53035895,
#         0.6015658 , 0.6115968 , 0.61701076, 0.55044746, 0.62627742,
#         0.60206474]),
#  'std_test_score': array([0.04358239, 0.15262536, 0.14076672, 0.06854858, 0.09779536,
#         0.03496197, 0.04100512, 0.06898545, 0.07409337, 0.07310738,
#         0.02183719, 0.05047529, 0.06268264, 0.05915891, 0.04089762,
#         0.04722964]),
#  'rank_test_score': array([ 1, 16, 12,  2, 15,  9,  5,  3,  7, 14, 11,  8,  6, 13,  4, 10])}

# %%
print(f'r2_score for the best parameter of Decision Tree is : ',grid.best_params_)
# Out:
# r2_score for the best parameter of Decision Tree is :  {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.013088      0.001911         0.006683        0.002097
# 1        0.011436      0.003173         0.005770        0.001700
# 2        0.009857      0.002323         0.004762        0.006292
# 3        0.004760      0.006289         0.012507        0.006254
# 4        0.015627      0.000001         0.006250        0.007655
# 5        0.012500      0.006250         0.006248        0.007652
# 6        0.015621      0.000005         0.008555        0.007144
# 7        0.008786      0.007384         0.009940        0.003547
# 8        0.036117      0.010864         0.000801        0.001601
# 9        0.029403      0.010828         0.004397        0.003689
# 10       0.029237      0.002823         0.010066        0.005943
# 11       0.021695      0.007269         0.007303        0.006622
# 12       0.013392      0.003704         0.008757        0.008031
# 13       0.009400      0.005129         0.007434        0.004935
# 14       0.014309      0.006907         0.004822        0.007389
# 15       0.010628      0.006537         0.004536        0.006190
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.618995
# 1   {'criterion': 'squared_error', 'max_features':...           0.657118
# 2   {'criterion': 'squared_error', 'max_features':...           0.600475
# 3   {'criterion': 'squared_error', 'max_features':...           0.669124
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.525620
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.588494
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.622717
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.595055
# 8   {'criterion': 'absolute_error', 'max_features'...           0.700189
# 9   {'criterion': 'absolute_error', 'max_features'...           0.544913
# 10  {'criterion': 'absolute_error', 'max_features'...           0.559575
# 11  {'criterion': 'absolute_error', 'max_features'...           0.540250
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.637309
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.501556
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.693704
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.609046
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.599779           0.710539           0.700504
# 1            0.516870           0.346018           0.222137
# 2            0.635089           0.298060           0.635544
# 3            0.543280           0.753341           0.619382
# 4            0.339566           0.612530           0.475241
# 5            0.648256           0.584251           0.574222
# 6            0.606620           0.639710           0.553868
# 7            0.544698           0.737514           0.673470
# 8            0.555485           0.688839           0.509318
# 9            0.475062           0.459520           0.508014
# 10           0.600858           0.615555           0.618449
# 11           0.624058           0.677169           0.648072
# 12           0.525784           0.691023           0.563369
# 13           0.651911           0.552831           0.482362
# 14           0.647360           0.606257           0.574341
# 15           0.618129           0.675829           0.572624
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.662490         0.658461        0.043582                1
# 1            0.530442         0.454517        0.152625               16
# 2            0.695324         0.572898        0.140767               12
# 3            0.631357         0.643297        0.068549                2
# 4            0.592532         0.509098        0.097795               15
# 5            0.657371         0.610519        0.034962                9
# 6            0.678817         0.620347        0.041005                5
# 7            0.586635         0.627474        0.068985                3
# 8            0.606522         0.612071        0.074093                7
# 9            0.664286         0.530359        0.073107               14
# 10           0.613392         0.601566        0.021837               11
# 11           0.568435         0.611597        0.050475                8
# 12           0.667568         0.617011        0.062683                6
# 13           0.563578         0.550447        0.059159               13
# 14           0.609725         0.626277        0.040898                4
# 15           0.534696         0.602065        0.047230               10

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
result=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
res
